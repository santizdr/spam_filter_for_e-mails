# %% [markdown]
# # Filtrado de correo electrónico con scikit-learn y NLTK

# %%
# Imports
import nltk
import sklearn
import numpy as np 
import pandas as pd
from email import *
import os.path
import glob

# %%
from google.colab import files
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6728/2535520808.py in <module>
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %%
from nltk.corpus import PlaintextCorpusReader

# %%
corpus_root = r'C:\Users\santi\Documents\wsp_py\EvalPracticaIA\Enron-Spam\legítimo'
wordlists = PlaintextCorpusReader(corpus_root, '.*')
wordlists.fileids()
# Out:
# ['0',
#  '1',
#  '1000',
#  '10001',
#  '10002',
#  '10003',
#  '10004',
#  '10005',
#  '10006',
#  '10007',
#  '10008',
#  '10009',
#  '1001',
#  '10010',
#  '10011',
#  '10012',
#  '10014',
#  '10015',
#  '10016',
#  '10019',
#  '1002',
#  '10020',
#  '10021',
#  '10022',
#  '10023',
#  '10024',
#  '10025',
#  '10026',
#  '10028',
#  '10029',
#  '10030',
#  '10031',
#  '10032',
#  '10034',
#  '10035',
#  '10036',
#  '10037',
#  '10038',
#  '10039',
#  '1004',
#  '10042',
#  '10044',
#  '10045',
#  '10048',
#  '10049',
#  '1005',
#  '10050',
#  '10051',
#  '10055',
#  '10056',
#  '10057',
#  '10058',
#  '10059',
#  '1006',
#  '10060',
#  '10061',
#  '10062',
#  '10064',
#  '10065',
#  '10066',
#  '10067',
#  '10068',
#  '10069',
#  '1007',
#  '10071',
#  '10073',
#  '10074',
#  '10075',
#  '10076',
#  '10078',
#  '10079',
#  '10080',
#  '10082',
#  '10083',
#  '10086',
#  '10087',
#  '10088',
#  '10089',
#  '10090',
#  '10091',
#  '10092',
#  '10093',
#  '10094',
#  '10096',
# ...

# %%
wordlists.words('2')
# Out:
# ['Message', '-', 'ID', ':', '<', '17666957', '.', ...]

# %%
f = open(r"C:\Users\santi\Documents\wsp_py\EvalPracticaIA\Enron-Spam\legitimo\0", "r")
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6728/2596549310.py in <module>
# ----> 1 f = open(r"C:\Users\santi\Documents\wsp_py\EvalPracticaIA\Enron-Spam\legitimo\0", "r")
#       2 print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\santi\\Documents\\wsp_py\\EvalPracticaIA\\Enron-Spam\\legitimo\\0'

# %%
ruta = r'C:\Users\santi\Documents\wsp_py\EvalPracticaIA\Enron-Spam\legítimo'
words_in_mail = []
for infile in glob.glob(os.path.join(ruta, '0*')):
    file = open(infile, 'r')
    email.message_from_binary_file(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6728/3446268151.py in <module>
#       3 for infile in glob.glob(os.path.join(ruta, '0*')):
#       4     file = open(infile, 'r')
# ----> 5     email.message_from_binary_file(file)
#
# NameError: name 'email' is not defined

# %%
contenido = os.listdir(r'C:\Users\santi\Documents\wsp_py\EvalPracticaIA\Enron-Spam\legítimo')
contenido
# Out:
# ['0',
#  '1',
#  '1000',
#  '10001',
#  '10002',
#  '10003',
#  '10004',
#  '10005',
#  '10006',
#  '10007',
#  '10008',
#  '10009',
#  '1001',
#  '10010',
#  '10011',
#  '10012',
#  '10014',
#  '10015',
#  '10016',
#  '10019',
#  '1002',
#  '10020',
#  '10021',
#  '10022',
#  '10023',
#  '10024',
#  '10025',
#  '10026',
#  '10028',
#  '10029',
#  '10030',
#  '10031',
#  '10032',
#  '10034',
#  '10035',
#  '10036',
#  '10037',
#  '10038',
#  '10039',
#  '1004',
#  '10042',
#  '10044',
#  '10045',
#  '10048',
#  '10049',
#  '1005',
#  '10050',
#  '10051',
#  '10055',
#  '10056',
#  '10057',
#  '10058',
#  '10059',
#  '1006',
#  '10060',
#  '10061',
#  '10062',
#  '10064',
#  '10065',
#  '10066',
#  '10067',
#  '10068',
#  '10069',
#  '1007',
#  '10071',
#  '10073',
#  '10074',
#  '10075',
#  '10076',
#  '10078',
#  '10079',
#  '10080',
#  '10082',
#  '10083',
#  '10086',
#  '10087',
#  '10088',
#  '10089',
#  '10090',
#  '10091',
#  '10092',
#  '10093',
#  '10094',
#  '10096',
# ...

# %%
def mail_to_string(path):
    aux = []
    for file in contenido:
        for infile in glob.glob(os.path.join(path, file)):
            file = open(infile, 'r').read()
            aux.append(file)
    return aux

# %%
ruta = r'C:\Users\santi\Documents\wsp_py\EvalPracticaIA\Enron-Spam\legítimo'
mails = [mail for mail in mail_to_string(ruta)]

# %%
print(mails[0])
# Out:
# Message-ID: <26856793.1075855815701.JavaMail.evans@thyme>
# Date: Sun, 27 Aug 2000 06:10:00 -0700 (PDT)
# From: john.sorrells@enron.com
# To: donna.lowry@enron.com, richard.lauer@enron.com
# Subject: Reporting
# Cc: sally.beck@enron.com, wes.colwell@enron.com, ted.murphy@enron.com
# Mime-Version: 1.0
# Content-Type: text/plain; charset=us-ascii
# Content-Transfer-Encoding: 7bit
# Bcc: sally.beck@enron.com, wes.colwell@enron.com, ted.murphy@enron.com
# X-From: John Sorrells
# X-To: Donna Lowry, Richard Lauer
# X-cc: Sally Beck, Wes Colwell, Ted Murphy
# X-bcc:
# X-Origin: Beck-S
# X-FileName: sbeck.nsf
#
# Donna,
#
# Attached are the report and matrix for EOL, EOL Phase II (matrix for EOL is
# combined for the two reports) and Risk Controls Group.  Call me if you have
# any questions.
#
# John
